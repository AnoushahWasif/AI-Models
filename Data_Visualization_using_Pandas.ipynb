# %%
import pandas as pd
import numpy as np
pd.set_option('display.min_rows', 20)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb35baf5-f814-4286-99bc-e732062b05b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb35baf5-f814-4286-99bc-e732062b05b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Read from CSV file into dataframes

# %%
f = open('Cities.csv')
cities = pd.read_csv(f)

# %%
cities
# Out:
#             city         country  latitude  longitude  temperature
# 0        Aalborg         Denmark     57.03       9.92         7.52
# 1       Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2         Abisko          Sweden     63.35      18.83         0.20
# 3          Adana          Turkey     36.99      35.32        18.67
# 4       Albacete           Spain     39.00      -1.87        12.62
# 5      Algeciras           Spain     36.13      -5.47        17.38
# 6         Amiens          France     49.90       2.30        10.17
# 7      Amsterdam     Netherlands     52.35       4.92         8.93
# 8         Ancona           Italy     43.60      13.50        13.52
# 9        Andorra         Andorra     42.50       1.52         9.60
# ..           ...             ...       ...        ...          ...
# 203       Vienna         Austria     48.20      16.37         7.86
# 204         Vigo           Spain     42.22      -8.73        12.85
# ...

# %%
len(cities)
# Out:
# 213

# %%
cities.head()
# Out:
#        city         country  latitude  longitude  temperature
# 0   Aalborg         Denmark     57.03       9.92         7.52
# 1  Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2    Abisko          Sweden     63.35      18.83         0.20
# 3     Adana          Turkey     36.99      35.32        18.67
# 4  Albacete           Spain     39.00      -1.87        12.62

# %%
cities.tail()
# Out:
#             city      country  latitude  longitude  temperature
# 208  Yevpatoriya      Ukraine     45.20      33.36        10.02
# 209     Zaragoza        Spain     41.65      -0.89        14.17
# 210     Zhytomyr      Ukraine     50.25      28.66         6.67
# 211    Zonguldak       Turkey     41.43      31.78        10.64
# 212       Zurich  Switzerland     47.38       8.56         6.68

# %% [markdown]
# Sorting, selecting rows and columns

# %%
#Sort country then descending temperature
cities.sort_values(['country', 'temperature'], ascending=[True,False])
# Out:
#            city         country  latitude  longitude  temperature
# 78      Elbasan         Albania     41.12      20.08        15.18
# 9       Andorra         Andorra     42.50       1.52         9.60
# 203      Vienna         Austria     48.20      16.37         7.86
# 95         Graz         Austria     47.08      15.41         6.91
# 125        Linz         Austria     48.32      14.29         6.79
# 175    Salzburg         Austria     47.81      13.04         4.62
# 105   Innsbruck         Austria     47.28      11.41         4.54
# 47        Brest         Belarus     52.10      23.70         6.73
# 161       Pinsk         Belarus     52.13      26.09         6.42
# 138       Mazyr         Belarus     52.05      29.27         6.25
# ..          ...             ...       ...        ...          ...
# 58    Cambridge  United Kingdom     52.20       0.12         9.25
# 34    Blackpool  United Kingdom     53.83      -3.05         9.15
# ...

# %%
#select single column - returns a 'series'
cities.city
#Also show cities['city'], cities['temperature'], cities.temperature
# Out:
# 0          Aalborg
# 1         Aberdeen
# 2           Abisko
# 3            Adana
# 4         Albacete
# 5        Algeciras
# 6           Amiens
# 7        Amsterdam
# 8           Ancona
# 9          Andorra
#           ...
# 203         Vienna
# 204           Vigo
# 205        Vilnius
# 206         Warsaw
# 207        Wroclaw
# 208    Yevpatoriya
# 209       Zaragoza
# 210       Zhytomyr
# 211      Zonguldak
# 212         Zurich
# Name: city, Length: 213, dtype: object

# %%
#selecting multiple columns - return a dataframe
cities[['city', 'temperature']]
#Also show cities[['city']]
# Out:
#             city  temperature
# 0        Aalborg         7.52
# 1       Aberdeen         8.10
# 2         Abisko         0.20
# 3          Adana        18.67
# 4       Albacete        12.62
# 5      Algeciras        17.38
# 6         Amiens        10.17
# 7      Amsterdam         8.93
# 8         Ancona        13.52
# 9        Andorra         9.60
# ..           ...          ...
# 203       Vienna         7.86
# 204         Vigo        12.85
# 205      Vilnius         5.38
# 206       Warsaw         7.20
# 207      Wroclaw         7.17
# 208  Yevpatoriya        10.02
# 209     Zaragoza        14.17
# 210     Zhytomyr         6.67
# 211    Zonguldak        10.64
# 212       Zurich         6.68
#
# [213 rows x 2 columns]

# %%
#Selecting rows based on condition
#Note: no need to do data conversion - pandas infers types for columns
cities[cities.longitude < 0]
# Out:
#             city         country  latitude  longitude  temperature
# 1       Aberdeen  United Kingdom     57.17      -2.08         8.10
# 4       Albacete           Spain     39.00      -1.87        12.62
# 5      Algeciras           Spain     36.13      -5.47        17.38
# 10        Angers          France     47.48      -0.53        10.98
# 17       Badajoz           Spain     38.88      -6.97        15.61
# 24       Belfast  United Kingdom     54.60      -5.96         8.48
# 32        Bilbao           Spain     43.25      -2.93        11.41
# 33    Birmingham  United Kingdom     52.47      -1.92         8.81
# 34     Blackpool  United Kingdom     53.83      -3.05         9.15
# 38      Bordeaux          France     44.85      -0.60        11.87
# 40   Bournemouth  United Kingdom     50.73      -1.90         9.97
# 41      Bradford  United Kingdom     53.80      -1.75         8.39
# 42         Braga        Portugal     41.55      -8.42        13.42
# ...

# %%
#Selecting rows by number
cities[15:20]
#show cities[:8] and cities [200:]
# Out:
#          city  country  latitude  longitude  temperature
# 15   Augsburg  Germany     48.35      10.90         4.54
# 16      Bacau  Romania     46.58      26.92         7.51
# 17    Badajoz    Spain     38.88      -6.97        15.61
# 18  Baia Mare  Romania     47.66      23.58         8.87
# 19      Balti  Moldova     47.76      27.91         8.23

# %%
cities[8:]
# Out:
#             city      country  latitude  longitude  temperature
# 8         Ancona        Italy     43.60      13.50        13.52
# 9        Andorra      Andorra     42.50       1.52         9.60
# 10        Angers       France     47.48      -0.53        10.98
# 11        Ankara       Turkey     39.93      32.86         9.86
# 12       Antalya       Turkey     36.89      30.70        11.88
# 13          Arad      Romania     46.17      21.32         9.32
# 14        Athens       Greece     37.98      23.73        17.41
# 15      Augsburg      Germany     48.35      10.90         4.54
# 16         Bacau      Romania     46.58      26.92         7.51
# 17       Badajoz        Spain     38.88      -6.97        15.61
# ..           ...          ...       ...        ...          ...
# 203       Vienna      Austria     48.20      16.37         7.86
# 204         Vigo        Spain     42.22      -8.73        12.85
# 205      Vilnius    Lithuania     54.68      25.32         5.38
# ...

# %%
cities[200:]
# Out:
#             city      country  latitude  longitude  temperature
# 200        Turku      Finland     60.45      22.25         4.72
# 201      Uppsala       Sweden     59.86      17.64         4.17
# 202     Valencia        Spain     39.49      -0.40        16.02
# 203       Vienna      Austria     48.20      16.37         7.86
# 204         Vigo        Spain     42.22      -8.73        12.85
# 205      Vilnius    Lithuania     54.68      25.32         5.38
# 206       Warsaw       Poland     52.25      21.00         7.20
# 207      Wroclaw       Poland     51.11      17.03         7.17
# 208  Yevpatoriya      Ukraine     45.20      33.36        10.02
# 209     Zaragoza        Spain     41.65      -0.89        14.17
# 210     Zhytomyr      Ukraine     50.25      28.66         6.67
# 211    Zonguldak       Turkey     41.43      31.78        10.64
# 212       Zurich  Switzerland     47.38       8.56         6.68

# %%
#Putting it together: selecting rows, columns sorting
#City and longitude of all cities with latitude > 50
#temperature > 9 sorted by longitude
temp1 = cities[(cities.latitude > 50) & (cities.temperature > 9)]
temp2 = temp1[['city', 'longitude']]
temp3 = temp2.sort_values('longitude')
temp3
#show eliminating temp3, then temp2, then temp1
#note similar functuality to SQL
# Out:
#             city  longitude
# 88        Galway      -9.05
# 67          Cork      -8.50
# 188      Swansea      -3.95
# 84        Exeter      -3.53
# 34     Blackpool      -3.05
# 40   Bournemouth      -1.90
# 58     Cambridge       0.12
# 123        Lille       3.08
# 49        Brugge       3.23

# %%
#Putting it together: selecting rows, columns sorting
#City and longitude of all cities with latitude > 50
#temperature > 9 sorted by longitude
temp1 = cities[(cities.latitude > 50) & (cities.temperature > 9)]
temp2 = temp1[['city', 'longitude']]
temp2
#show eliminating temp3, then temp2, then temp1
#note similar functuality to SQL
# Out:
#             city  longitude
# 34     Blackpool      -3.05
# 40   Bournemouth      -1.90
# 49        Brugge       3.23
# 58     Cambridge       0.12
# 67          Cork      -8.50
# 84        Exeter      -3.53
# 88        Galway      -9.05
# 123        Lille       3.08
# 188      Swansea      -3.95

# %%
f = open('Countries.csv')
country = pd.read_csv(f)

# %%
country
# Out:
#                    country  population   EU coastline
# 0                  Albania        2.90   no       yes
# 1                  Andorra        0.07   no        no
# 2                  Austria        8.57  yes        no
# 3                  Belarus        9.48   no        no
# 4                  Belgium       11.37  yes       yes
# 5   Bosnia and Herzegovina        3.80   no       yes
# 6                 Bulgaria        7.10  yes       yes
# 7                  Croatia        4.23  yes       yes
# 8                   Cyprus        1.18  yes       yes
# 9           Czech Republic       10.55  yes        no
# 10                 Denmark        5.69  yes       yes
# 11                 Estonia        1.31  yes       yes
# 12                 Finland        5.52  yes       yes
# 13                  France       64.67  yes       yes
# 14                 Germany       80.68  yes       yes
# 15                  Greece       10.92  yes       yes
# ...

# %%
temp1 = country[(country.EU == 'no')  & (country.coastline =='no' )]
temp2 = temp1[['country', 'population']]
temp3 =temp2.sort_values('population')
temp3
# Out:
#           country  population
# 22  Liechtenstein        0.04
# 1         Andorra        0.07
# 20         Kosovo        1.91
# 25      Macedonia        2.08
# 26        Moldova        4.06
# 38    Switzerland        8.38
# 33         Serbia        8.81
# 3         Belarus        9.48

# %%
print('Minimim temperature', min(cities.temperature))
print('Maximum temperature', max(cities.temperature))
# Out:
# Minimim temperature -2.2
# Maximum temperature 18.67

# %%
print('Using numpy average:', np.average(cities.temperature))
print('Using built-in mean', cities.temperature.mean())
# Out:
# Using numpy average: 9.497840375586854
# Using built-in mean 9.497840375586854

# %%
cities.groupby('country').mean().temperature
# Out:
# country
# Albania                   15.180000
# Andorra                    9.600000
# Austria                    6.144000
# Belarus                    5.946667
# Belgium                    9.650000
# Bosnia and Herzegovina     9.600000
# Bulgaria                  10.440000
# Croatia                   10.865000
# Czech Republic             7.856667
# Denmark                    7.625000
# Estonia                    4.590000
# Finland                    3.487500
# France                    10.151111
# Germany                    7.869286
# Greece                    16.902500
# Hungary                    9.602500
# Ireland                    9.300000
# Italy                     13.474667
# Latvia                     5.270000
# Lithuania                  6.143333
# Macedonia                  9.360000
# Moldova                    8.415000
# Montenegro                 9.990000
# Netherlands                8.756667
# Norway                     3.726000
# Poland                     7.250000
# ...

# %%
print('Average of population:', country.groupby(['coastline', 'population']), np.average(country.population))
# Out:
# Average of population: <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f91a19f7190> 16.12547619047619

# %%
print('Average of population:', country.groupby(['population']), np.average(country.population))
# Out:
# Average of population: <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f919fc99eb0> 16.12547619047619

# %%
cities.merge(country, on='country')
# Out:
#             city                 country  latitude  longitude  temperature  \
# 0        Aalborg                 Denmark     57.03       9.92         7.52
# 1         Odense                 Denmark     55.40      10.38         7.73
# 2       Aberdeen          United Kingdom     57.17      -2.08         8.10
# 3        Belfast          United Kingdom     54.60      -5.96         8.48
# 4     Birmingham          United Kingdom     52.47      -1.92         8.81
# 5      Blackpool          United Kingdom     53.83      -3.05         9.15
# 6    Bournemouth          United Kingdom     50.73      -1.90         9.97
# 7       Bradford          United Kingdom     53.80      -1.75         8.39
# 8      Cambridge          United Kingdom     52.20       0.12         9.25
# 9         Dundee          United Kingdom     56.47      -3.00         6.40
# ..           ...                     ...       ...        ...          ...
# ...

# %%
country.merge(cities, on='country')
# Out:
#             country  population   EU coastline         city  latitude  \
# 0           Albania        2.90   no       yes      Elbasan     41.12
# 1           Andorra        0.07   no        no      Andorra     42.50
# 2           Austria        8.57  yes        no         Graz     47.08
# 3           Austria        8.57  yes        no    Innsbruck     47.28
# 4           Austria        8.57  yes        no         Linz     48.32
# 5           Austria        8.57  yes        no     Salzburg     47.81
# 6           Austria        8.57  yes        no       Vienna     48.20
# 7           Belarus        9.48   no        no        Brest     52.10
# 8           Belarus        9.48   no        no       Hrodna     53.68
# 9           Belarus        9.48   no        no        Mazyr     52.05
# ..              ...         ...  ...       ...          ...       ...
# 203  United Kingdom       65.11  yes       yes    Blackpool     53.83
# ...

# %%
country[country.country.str.contains('ia')]
# Out:
#                    country  population   EU coastline
# 0                  Albania        2.90   no       yes
# 2                  Austria        8.57  yes        no
# 5   Bosnia and Herzegovina        3.80   no       yes
# 6                 Bulgaria        7.10  yes       yes
# 7                  Croatia        4.23  yes       yes
# 11                 Estonia        1.31  yes       yes
# 21                  Latvia        1.96  yes       yes
# 23               Lithuania        2.85  yes       yes
# 25               Macedonia        2.08   no        no
# 32                 Romania       19.37  yes       yes
# 33                  Serbia        8.81   no        no
# 34                Slovakia        5.43  yes        no
# 35                Slovenia        2.07  yes       yes

# %%
cities['fahrenhite'] = (cities.temperature * 9/5) + 32
cities
# Out:
#             city         country  latitude  longitude  temperature  fahrenhite
# 0        Aalborg         Denmark     57.03       9.92         7.52      45.536
# 1       Aberdeen  United Kingdom     57.17      -2.08         8.10      46.580
# 2         Abisko          Sweden     63.35      18.83         0.20      32.360
# 3          Adana          Turkey     36.99      35.32        18.67      65.606
# 4       Albacete           Spain     39.00      -1.87        12.62      54.716
# 5      Algeciras           Spain     36.13      -5.47        17.38      63.284
# 6         Amiens          France     49.90       2.30        10.17      50.306
# 7      Amsterdam     Netherlands     52.35       4.92         8.93      48.074
# 8         Ancona           Italy     43.60      13.50        13.52      56.336
# 9        Andorra         Andorra     42.50       1.52         9.60      49.280
# ..           ...             ...       ...        ...          ...         ...
# ...

# %%
temp1 = cities[cities.latitude > 50]
temp2 = country[country.EU == 'no']
temp1.merge(temp2)
# Out:
#          city  country  latitude  longitude  temperature  fahrenhite  \
# 0      Bergen   Norway     60.39       5.32         1.75      35.150
# 1        Bodo   Norway     67.25      14.40         4.50      40.100
# 2        Oslo   Norway     59.92      10.75         2.32      36.176
# 3   Stavanger   Norway     58.97       5.68         5.53      41.954
# 4   Trondheim   Norway     63.42      10.42         4.53      40.154
# 5       Brest  Belarus     52.10      23.70         6.73      44.114
# 6      Hrodna  Belarus     53.68      23.83         6.07      42.926
# 7       Mazyr  Belarus     52.05      29.27         6.25      43.250
# 8       Minsk  Belarus     53.90      27.57         5.28      41.504
# 9       Orsha  Belarus     54.52      30.42         4.93      40.874
# 10      Pinsk  Belarus     52.13      26.09         6.42      43.556
# 11  Chernihiv  Ukraine     51.50      31.30         5.92      42.656
# 12       Kiev  Ukraine     50.43      30.52         6.88      44.384
# ...

# %%
cities[cities.longitude > 35]
print(cities[cities.longitude > 35])
cities[cities.longitude > -5]
# Out:
#           city  country  latitude  longitude  temperature  fahrenhite
# 3        Adana   Turkey     36.99      35.32        18.67      65.606
# 23      Batman   Turkey     37.89      41.14        14.16      57.488
# 81    Erzincan   Turkey     39.75      39.49         8.67      47.606
# 82     Erzurum   Turkey     39.92      41.29         5.17      41.306
# 89   Gaziantep   Turkey     37.07      37.38        13.46      56.228
# 101   Horlivka  Ukraine     48.30      38.05         7.12      44.816
# 112    Kayseri   Turkey     38.73      35.49         8.89      48.002
# 132  Makiyivka  Ukraine     48.03      37.97         8.70      47.660
# 133    Malatya   Turkey     38.37      38.30        14.13      57.434
# 150       Ordu   Turkey     41.00      37.87        11.92      53.456
# 176     Samsun   Turkey     41.28      36.34        12.05      53.690
# 180      Siirt   Turkey     37.94      41.93        12.48      54.464
# ...

# %% [markdown]
# WORLD CUP DATA

# %%
import pandas as pd
import numpy as np
pd.set_option('display.min_rows', 20)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ded79a0e-f572-4454-b8e5-53e8e49be7a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ded79a0e-f572-4454-b8e5-53e8e49be7a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Read from CSV file into dataframes

# %%
f = open('Teams.csv')
Teams = pd.read_csv(f)

# %%
Teams
# Out:
#             team  ranking  games  wins  draws  losses  goalsFor  goalsAgainst  \
# 0         Brazil        1      5     3      1       1         9             4
# 1          Spain        2      6     5      0       1         7             2
# 2       Portugal        3      4     1      2       1         7             1
# 3    Netherlands        4      6     6      0       0        12             5
# 4          Italy        5      3     0      2       1         4             5
# 5        Germany        6      6     4      0       2        13             3
# 6      Argentina        7      5     4      0       1        10             6
# 7        England        8      4     1      2       1         3             5
# 8         France        9      3     0      1       2         1             4
# 9         Greece       13      3     1      0       2         2             5
# 10           USA       14      4     1      2       1         5             5
# ...

# %% [markdown]
# Read from CSV file into dataframes

# %%
f = open('Players.csv')
Players = pd.read_csv(f)

# %%
Players
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# 5         Djebbour  Algeria     forward      123      3      19        1
# 6          Ghezzal  Algeria     forward       40      3       8        0
# 7        Guedioura  Algeria  midfielder       38      0      18        1
# 8         Halliche  Algeria    defender      270      2      94        4
# 9            Kadir  Algeria  midfielder      262      0     104        3
# ..             ...      ...         ...      ...    ...     ...      ...
# 585        Donovan      USA     forward      390      7     165        9
# ...

# %% [markdown]
# # 1

# %%
Players.surname[Players.team.str.contains('ia') & (Players.minutes <200)& (Players.passes >100)]
# Out:
# 431    Kuzmanovic
# Name: surname, dtype: object

# %% [markdown]
# # 2

# %%
Players.passes[Players.position.str.contains('midfielder')].mean()
# Out:
# 95.2719298245614

# %%
Players.passes[Players.position.str.contains('forward')].mean()
# Out:
# 50.82517482517483

# %% [markdown]
# # 3

# %%
Teams['Ratio'] = (Teams.goalsFor /  Teams.goalsAgainst)
Teams
# Out:
#             team  ranking  games  wins  draws  losses  goalsFor  goalsAgainst  \
# 0         Brazil        1      5     3      1       1         9             4
# 1          Spain        2      6     5      0       1         7             2
# 2       Portugal        3      4     1      2       1         7             1
# 3    Netherlands        4      6     6      0       0        12             5
# 4          Italy        5      3     0      2       1         4             5
# 5        Germany        6      6     4      0       2        13             3
# 6      Argentina        7      5     4      0       1        10             6
# 7        England        8      4     1      2       1         3             5
# 8         France        9      3     0      1       2         1             4
# 9         Greece       13      3     1      0       2         2             5
# 10           USA       14      4     1      2       1         5             5
# ...

# %%
t = Teams.sort_values(['Ratio'], ascending=[False]).head(1)
t.team
# Out:
# 2    Portugal
# Name: team, dtype: object

# %%
temp = Players.merge(Teams,on='team')
print(len(temp[(temp.ranking < 10) & (temp.minutes>350)]))
# Out:
# 54

# %%
``````````````````````````````````````````````````````
